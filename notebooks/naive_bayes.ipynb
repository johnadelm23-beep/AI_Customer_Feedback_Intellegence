# %%
import pandas as pd
from scipy.sparse import load_npz
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
X_train = load_npz('X_train_tfidf.npz')
X_test = load_npz('X_test_tfidf.npz')

y_train = pd.read_csv('y_train.csv').values.ravel()
y_test = pd.read_csv('y_test.csv').values.ravel()

print('X_train:', X_train.shape)
print('X_test:', X_test.shape)
print('y_train:', y_train.shape)
print('y_test:', y_test.shape)
# Out:
# X_train: (15853, 5000)
# X_test: (3964, 5000)
# y_train: (15853,)
# y_test: (3964,)

# %%
nb_model = MultinomialNB()

nb_model.fit(X_train, y_train)
y_pred = nb_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print('Accuracy:', accuracy * 100)
print('Precision:', precision * 100)
print('Recall:', recall * 100)
print('F1 Score:', f1 * 100)
# Out:
# Accuracy: 90.76690211907164
# Precision: 90.7446250327422
# Recall: 99.62579159470352
# F1 Score: 94.97804911510496

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.10      0.18       490
#            1       0.89      1.00      0.94      3474
#
#     accuracy                           0.89      3964
#    macro avg       0.92      0.55      0.56      3964
# weighted avg       0.90      0.89      0.85      3964

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[ 137  353]
#  [  13 3461]]
